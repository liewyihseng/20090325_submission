# %% [markdown]
# # Import

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
from sklearn.model_selection import KFold
from functions.common_function import *
from functions.initialize_model import initialize_model_expanded
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from scipy.stats import pearsonr

'''Enabling plotting of graphs just below the plotting commands'''
# %matplotlib inline
'''Enabling the disply of all rows and columns within the dataframe'''
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %% [markdown]
# # Constant

# %%
num_feature = 8
cat_col = [4, 5]
num_ori_feature = num_feature - len(cat_col)
num_target = 3
limit = pd.DataFrame({'lower' : [303, 20, 0, 2, 0, 0, 0, 0, 122, 1236, 14], \
                     'higher' : [840, 44, 17, 5, 1, 1, 1, 1, 408, 3240, 101], \
                     'ref' : [530, 40, 14, 3.2, np.nan, np.nan,np.nan, np.nan, np.nan, np.nan, np.nan]})


'''Import dataset'''
dataset = pd.read_csv("Dataset/Choudhury_Expanded_Dataset.csv")

# %% [markdown]
# # Implementation

# %%
'''Converting Categorical Data into binary representation'''
converted_dataset = convert_cat(dataset, cat_col, num_ori_feature, num_target, [dataset.iloc[:, 4].unique(), dataset.iloc[:, 5].unique()])

'''Normalising dataset according to higher and lower limit values'''
normalised_dataset = normalise(converted_dataset, limit)

'''Feature Target Splitting'''
feature, target = x_y_split(normalised_dataset, num_feature, num_target)

'''Model Fitting'''
linear_reg_model = LinearRegression()
MAE = abs(cross_val_score(linear_reg_model, feature, target, cv= 10, scoring= 'neg_mean_absolute_error'))
MSE = abs(cross_val_score(linear_reg_model, feature, target, cv= 10, scoring= 'neg_mean_squared_error' ))
RMSE = abs(cross_val_score(linear_reg_model, feature, target, cv= 10, scoring= 'neg_root_mean_squared_error' ))


'''Provide average score'''
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(MAE)):
    print('------------------------------------------------------------------------')
    print(f'> Fold {i+1} - MAE: {MAE[i]} - MSE: {MSE[i]}- RMSE: {RMSE[i]}') 
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> MAE: {np.mean(MAE)} - Standard Deviation: {np.std(MAE)}')
print(f'> MSE: {np.mean(MSE)}')
print(f'> RMSE: {np.mean(RMSE)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - MAE: 0.04486432406774848 - MSE: 0.0028517722274715046- RMSE: 0.050894602468578944
# ------------------------------------------------------------------------
# > Fold 2 - MAE: 0.020671492940136982 - MSE: 0.0004934710769321526- RMSE: 0.02116473051317934
# ------------------------------------------------------------------------
# > Fold 3 - MAE: 0.016441918389223906 - MSE: 0.0004374395915505121- RMSE: 0.020173816853077117
# ------------------------------------------------------------------------
# > Fold 4 - MAE: 0.09321002303599273 - MSE: 0.011856846139160002- RMSE: 0.10267699907598456
# ------------------------------------------------------------------------
# > Fold 5 - MAE: 0.052437406570096406 - MSE: 0.0034978681537334473- RMSE: 0.05341641995521726
# ------------------------------------------------------------------------
# > Fold 6 - MAE: 0.02441457676640188 - MSE: 0.000853009822446328- RMSE: 0.028420029526211327
# ------------------------------------------------------------------------
# > Fold 7 - MAE: 0.05219770365226323 - MSE: 0.0171869386736335- RMSE: 0.1096722211302338
# ------------------------------------------------------------------------
# > Fold 8 - MAE: 0.011437181497286527 - MSE: 0.00023051228703696052- RMSE: 0.0117289739945404
# ------------------------------------------------------------------------
# > Fold 9 - MAE: 0.009312578355619555 - MSE: 0.00012992481790434864- RMSE: 0.009551933384988774
# ------------------------------------------------------------------------
# > Fold 10 - MAE: 0.015004812141260851 - MSE: 0.00043151782287528735- RMSE: 0.01966869561467724
# ------------------------------------------------------------------------
# Average scores for all folds:
# > MAE: 0.03399920174160305 - Standard Deviation: 0.025203446461013246
# > MSE: 0.003796930061274404
# > RMSE: 0.042736842251668884
# ------------------------------------------------------------------------

# %%
linear_reg_model  = LinearRegression()
X_train, X_test, Y_train, Y_test = train_test_split(feature, target, test_size = 0.20, random_state = 0)
linear_reg_model.fit(X_train, Y_train)
Y_pred = linear_reg_model.predict(X_test)
prediction = pd.DataFrame(Y_pred, columns = get_col_names(target))

'''Preparation to Rescale target values'''
min_y = limit.iloc[num_feature: num_feature + num_target, 0].to_list()
max_y = limit.iloc[num_feature: num_feature + num_target, 1].to_list()

corr_list = []
'''Tabulating the differences of Expected and Predictions made by the ANN Model'''
for i in range(len(X_test)):
    '''Rescaling of normalised data'''
    expected = pd.DataFrame(inverse_transform(Y_test.iloc[i].to_list(), max_y, min_y))
    predicted = pd.DataFrame(inverse_transform(prediction.iloc[i].to_list(), max_y, min_y))
    comparison_df = pd.concat([expected, predicted], axis = 1)
    comparison_df.columns = ['Expected', 'Predicted']
    comparison_df.index = get_col_names(target)
    display(comparison_df.style.set_caption(f"Element {i + 1}"))
    corr, _ = pearsonr(expected.iloc[:, 0].tolist(), predicted.iloc[:, 0].tolist())
    corr_list.append(corr)
    
'''Provide average score'''
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(corr_list)):
    print('------------------------------------------------------------------------')
    print(f'> Iteration {i+1} - Pearson Correlation: {corr_list[i]}') 
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Average Pearsons Correlation: {np.mean(corr_list)} - Standard Deviation: {np.std(corr_list)}')
print('------------------------------------------------------------------------')
# Out:
# <style type="text/css">
# </style>
# <table id="T_a375b_">
#   <caption>Element 1</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a375b_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_a375b_row0_col0" class="data row0 col0" >281.000000</td>
#       <td id="T_a375b_row0_col1" class="data row0 col1" >282.296290</td>
#     </tr>
#     <tr>
#       <th id="T_a375b_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_a375b_row1_col0" class="data row1 col0" >2453.000000</td>
#       <td id="T_a375b_row1_col1" class="data row1 col1" >2454.139099</td>
#     </tr>
#     <tr>
#       <th id="T_a375b_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_a375b_row2_col0" class="data row2 col0" >55.000000</td>
#       <td id="T_a375b_row2_col1" class="data row2 col1" >54.606765</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_b5dcd_">
#   <caption>Element 2</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b5dcd_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_b5dcd_row0_col0" class="data row0 col0" >258.000000</td>
#       <td id="T_b5dcd_row0_col1" class="data row0 col1" >246.051654</td>
#     </tr>
#     <tr>
#       <th id="T_b5dcd_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_b5dcd_row1_col0" class="data row1 col0" >2342.000000</td>
#       <td id="T_b5dcd_row1_col1" class="data row1 col1" >2194.663672</td>
#     </tr>
#     <tr>
#       <th id="T_b5dcd_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_b5dcd_row2_col0" class="data row2 col0" >44.000000</td>
#       <td id="T_b5dcd_row2_col1" class="data row2 col1" >41.863575</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_6609d_">
#   <caption>Element 3</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6609d_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_6609d_row0_col0" class="data row0 col0" >281.000000</td>
#       <td id="T_6609d_row0_col1" class="data row0 col1" >282.296290</td>
#     </tr>
#     <tr>
#       <th id="T_6609d_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_6609d_row1_col0" class="data row1 col0" >2455.000000</td>
#       <td id="T_6609d_row1_col1" class="data row1 col1" >2454.139099</td>
#     </tr>
#     <tr>
#       <th id="T_6609d_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_6609d_row2_col0" class="data row2 col0" >55.000000</td>
#       <td id="T_6609d_row2_col1" class="data row2 col1" >54.606765</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_abb5b_">
#   <caption>Element 4</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_abb5b_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_abb5b_row0_col0" class="data row0 col0" >255.000000</td>
#       <td id="T_abb5b_row0_col1" class="data row0 col1" >255.223580</td>
#     </tr>
#     <tr>
#       <th id="T_abb5b_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_abb5b_row1_col0" class="data row1 col0" >2363.000000</td>
#       <td id="T_abb5b_row1_col1" class="data row1 col1" >2351.197307</td>
#     </tr>
#     <tr>
#       <th id="T_abb5b_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_abb5b_row2_col0" class="data row2 col0" >49.000000</td>
#       <td id="T_abb5b_row2_col1" class="data row2 col1" >47.134624</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_1c5b3_">
#   <caption>Element 5</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1c5b3_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_1c5b3_row0_col0" class="data row0 col0" >275.000000</td>
#       <td id="T_1c5b3_row0_col1" class="data row0 col1" >267.099830</td>
#     </tr>
#     <tr>
#       <th id="T_1c5b3_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_1c5b3_row1_col0" class="data row1 col0" >2421.000000</td>
#       <td id="T_1c5b3_row1_col1" class="data row1 col1" >2397.352248</td>
#     </tr>
#     <tr>
#       <th id="T_1c5b3_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_1c5b3_row2_col0" class="data row2 col0" >52.000000</td>
#       <td id="T_1c5b3_row2_col1" class="data row2 col1" >49.838972</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_29e4e_">
#   <caption>Element 6</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_29e4e_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_29e4e_row0_col0" class="data row0 col0" >275.000000</td>
#       <td id="T_29e4e_row0_col1" class="data row0 col1" >274.400083</td>
#     </tr>
#     <tr>
#       <th id="T_29e4e_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_29e4e_row1_col0" class="data row1 col0" >2434.000000</td>
#       <td id="T_29e4e_row1_col1" class="data row1 col1" >2424.114410</td>
#     </tr>
#     <tr>
#       <th id="T_29e4e_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_29e4e_row2_col0" class="data row2 col0" >54.000000</td>
#       <td id="T_29e4e_row2_col1" class="data row2 col1" >52.427390</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_078d2_">
#   <caption>Element 7</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_078d2_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_078d2_row0_col0" class="data row0 col0" >255.000000</td>
#       <td id="T_078d2_row0_col1" class="data row0 col1" >254.777006</td>
#     </tr>
#     <tr>
#       <th id="T_078d2_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_078d2_row1_col0" class="data row1 col0" >2326.000000</td>
#       <td id="T_078d2_row1_col1" class="data row1 col1" >2347.410508</td>
#     </tr>
#     <tr>
#       <th id="T_078d2_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_078d2_row2_col0" class="data row2 col0" >47.000000</td>
#       <td id="T_078d2_row2_col1" class="data row2 col1" >48.213573</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_ee706_">
#   <caption>Element 8</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee706_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_ee706_row0_col0" class="data row0 col0" >264.000000</td>
#       <td id="T_ee706_row0_col1" class="data row0 col1" >257.605467</td>
#     </tr>
#     <tr>
#       <th id="T_ee706_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_ee706_row1_col0" class="data row1 col0" >2360.000000</td>
#       <td id="T_ee706_row1_col1" class="data row1 col1" >2320.949307</td>
#     </tr>
#     <tr>
#       <th id="T_ee706_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_ee706_row2_col0" class="data row2 col0" >48.000000</td>
#       <td id="T_ee706_row2_col1" class="data row2 col1" >46.906938</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_2f990_">
#   <caption>Element 9</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f990_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_2f990_row0_col0" class="data row0 col0" >259.000000</td>
#       <td id="T_2f990_row0_col1" class="data row0 col1" >266.533414</td>
#     </tr>
#     <tr>
#       <th id="T_2f990_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_2f990_row1_col0" class="data row1 col0" >2310.000000</td>
#       <td id="T_2f990_row1_col1" class="data row1 col1" >2418.533661</td>
#     </tr>
#     <tr>
#       <th id="T_2f990_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_2f990_row2_col0" class="data row2 col0" >47.000000</td>
#       <td id="T_2f990_row2_col1" class="data row2 col1" >50.804083</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_f4726_">
#   <caption>Element 10</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f4726_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_f4726_row0_col0" class="data row0 col0" >263.000000</td>
#       <td id="T_f4726_row0_col1" class="data row0 col1" >263.119787</td>
#     </tr>
#     <tr>
#       <th id="T_f4726_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_f4726_row1_col0" class="data row1 col0" >2391.000000</td>
#       <td id="T_f4726_row1_col1" class="data row1 col1" >2381.221996</td>
#     </tr>
#     <tr>
#       <th id="T_f4726_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_f4726_row2_col0" class="data row2 col0" >51.000000</td>
#       <td id="T_f4726_row2_col1" class="data row2 col1" >49.313998</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_3ff4d_">
#   <caption>Element 11</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3ff4d_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_3ff4d_row0_col0" class="data row0 col0" >261.000000</td>
#       <td id="T_3ff4d_row0_col1" class="data row0 col1" >248.152347</td>
#     </tr>
#     <tr>
#       <th id="T_3ff4d_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_3ff4d_row1_col0" class="data row1 col0" >2359.000000</td>
#       <td id="T_3ff4d_row1_col1" class="data row1 col1" >2217.624696</td>
#     </tr>
#     <tr>
#       <th id="T_3ff4d_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_3ff4d_row2_col0" class="data row2 col0" >45.000000</td>
#       <td id="T_3ff4d_row2_col1" class="data row2 col1" >42.780550</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_0b867_">
#   <caption>Element 12</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0b867_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_0b867_row0_col0" class="data row0 col0" >278.000000</td>
#       <td id="T_0b867_row0_col1" class="data row0 col1" >272.074883</td>
#     </tr>
#     <tr>
#       <th id="T_0b867_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_0b867_row1_col0" class="data row1 col0" >2435.000000</td>
#       <td id="T_0b867_row1_col1" class="data row1 col1" >2417.515062</td>
#     </tr>
#     <tr>
#       <th id="T_0b867_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_0b867_row2_col0" class="data row2 col0" >52.000000</td>
#       <td id="T_0b867_row2_col1" class="data row2 col1" >50.495189</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_084fe_">
#   <caption>Element 13</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_084fe_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_084fe_row0_col0" class="data row0 col0" >276.000000</td>
#       <td id="T_084fe_row0_col1" class="data row0 col1" >275.528113</td>
#     </tr>
#     <tr>
#       <th id="T_084fe_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_084fe_row1_col0" class="data row1 col0" >2436.000000</td>
#       <td id="T_084fe_row1_col1" class="data row1 col1" >2428.403651</td>
#     </tr>
#     <tr>
#       <th id="T_084fe_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_084fe_row2_col0" class="data row2 col0" >54.000000</td>
#       <td id="T_084fe_row2_col1" class="data row2 col1" >52.738730</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_c61c6_">
#   <caption>Element 14</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c61c6_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_c61c6_row0_col0" class="data row0 col0" >265.000000</td>
#       <td id="T_c61c6_row0_col1" class="data row0 col1" >255.504774</td>
#     </tr>
#     <tr>
#       <th id="T_c61c6_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_c61c6_row1_col0" class="data row1 col0" >2368.000000</td>
#       <td id="T_c61c6_row1_col1" class="data row1 col1" >2297.988282</td>
#     </tr>
#     <tr>
#       <th id="T_c61c6_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_c61c6_row2_col0" class="data row2 col0" >48.000000</td>
#       <td id="T_c61c6_row2_col1" class="data row2 col1" >45.989963</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_9370c_">
#   <caption>Element 15</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9370c_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_9370c_row0_col0" class="data row0 col0" >279.000000</td>
#       <td id="T_9370c_row0_col1" class="data row0 col1" >276.131465</td>
#     </tr>
#     <tr>
#       <th id="T_9370c_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_9370c_row1_col0" class="data row1 col0" >2435.000000</td>
#       <td id="T_9370c_row1_col1" class="data row1 col1" >2433.955510</td>
#     </tr>
#     <tr>
#       <th id="T_9370c_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_9370c_row2_col0" class="data row2 col0" >51.000000</td>
#       <td id="T_9370c_row2_col1" class="data row2 col1" >51.030258</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_8c022_">
#   <caption>Element 16</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8c022_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_8c022_row0_col0" class="data row0 col0" >262.000000</td>
#       <td id="T_8c022_row0_col1" class="data row0 col1" >249.202694</td>
#     </tr>
#     <tr>
#       <th id="T_8c022_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_8c022_row1_col0" class="data row1 col0" >2364.000000</td>
#       <td id="T_8c022_row1_col1" class="data row1 col1" >2229.105209</td>
#     </tr>
#     <tr>
#       <th id="T_8c022_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_8c022_row2_col0" class="data row2 col0" >46.000000</td>
#       <td id="T_8c022_row2_col1" class="data row2 col1" >43.239038</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_89177_">
#   <caption>Element 17</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_89177_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_89177_row0_col0" class="data row0 col0" >270.000000</td>
#       <td id="T_89177_row0_col1" class="data row0 col1" >268.759935</td>
#     </tr>
#     <tr>
#       <th id="T_89177_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_89177_row1_col0" class="data row1 col0" >2415.000000</td>
#       <td id="T_89177_row1_col1" class="data row1 col1" >2402.668203</td>
#     </tr>
#     <tr>
#       <th id="T_89177_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_89177_row2_col0" class="data row2 col0" >52.000000</td>
#       <td id="T_89177_row2_col1" class="data row2 col1" >50.870694</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_6b57a_">
#   <caption>Element 18</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6b57a_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_6b57a_row0_col0" class="data row0 col0" >250.000000</td>
#       <td id="T_6b57a_row0_col1" class="data row0 col1" >241.062507</td>
#     </tr>
#     <tr>
#       <th id="T_6b57a_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_6b57a_row1_col0" class="data row1 col0" >2269.000000</td>
#       <td id="T_6b57a_row1_col1" class="data row1 col1" >2140.131239</td>
#     </tr>
#     <tr>
#       <th id="T_6b57a_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_6b57a_row2_col0" class="data row2 col0" >41.000000</td>
#       <td id="T_6b57a_row2_col1" class="data row2 col1" >39.685759</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_b53d6_">
#   <caption>Element 19</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b53d6_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_b53d6_row0_col0" class="data row0 col0" >256.000000</td>
#       <td id="T_b53d6_row0_col1" class="data row0 col1" >256.351610</td>
#     </tr>
#     <tr>
#       <th id="T_b53d6_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_b53d6_row1_col0" class="data row1 col0" >2367.000000</td>
#       <td id="T_b53d6_row1_col1" class="data row1 col1" >2355.486548</td>
#     </tr>
#     <tr>
#       <th id="T_b53d6_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_b53d6_row2_col0" class="data row2 col0" >49.000000</td>
#       <td id="T_b53d6_row2_col1" class="data row2 col1" >47.445963</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_dd068_">
#   <caption>Element 20</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd068_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_dd068_row0_col0" class="data row0 col0" >261.000000</td>
#       <td id="T_dd068_row0_col1" class="data row0 col1" >260.863728</td>
#     </tr>
#     <tr>
#       <th id="T_dd068_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_dd068_row1_col0" class="data row1 col0" >2382.000000</td>
#       <td id="T_dd068_row1_col1" class="data row1 col1" >2372.643514</td>
#     </tr>
#     <tr>
#       <th id="T_dd068_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_dd068_row2_col0" class="data row2 col0" >50.000000</td>
#       <td id="T_dd068_row2_col1" class="data row2 col1" >48.691320</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_38fda_">
#   <caption>Element 21</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38fda_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_38fda_row0_col0" class="data row0 col0" >240.000000</td>
#       <td id="T_38fda_row0_col1" class="data row0 col1" >248.653863</td>
#     </tr>
#     <tr>
#       <th id="T_38fda_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_38fda_row1_col0" class="data row1 col0" >2251.000000</td>
#       <td id="T_38fda_row1_col1" class="data row1 col1" >2322.594737</td>
#     </tr>
#     <tr>
#       <th id="T_38fda_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_38fda_row2_col0" class="data row2 col0" >42.000000</td>
#       <td id="T_38fda_row2_col1" class="data row2 col1" >47.405921</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_4385a_">
#   <caption>Element 22</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4385a_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_4385a_row0_col0" class="data row0 col0" >268.000000</td>
#       <td id="T_4385a_row0_col1" class="data row0 col1" >267.631906</td>
#     </tr>
#     <tr>
#       <th id="T_4385a_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_4385a_row1_col0" class="data row1 col0" >2408.000000</td>
#       <td id="T_4385a_row1_col1" class="data row1 col1" >2398.378962</td>
#     </tr>
#     <tr>
#       <th id="T_4385a_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_4385a_row2_col0" class="data row2 col0" >52.000000</td>
#       <td id="T_4385a_row2_col1" class="data row2 col1" >50.559355</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_669ea_">
#   <caption>Element 23</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_669ea_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_669ea_row0_col0" class="data row0 col0" >248.000000</td>
#       <td id="T_669ea_row0_col1" class="data row0 col1" >251.945052</td>
#     </tr>
#     <tr>
#       <th id="T_669ea_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_669ea_row1_col0" class="data row1 col0" >2293.000000</td>
#       <td id="T_669ea_row1_col1" class="data row1 col1" >2335.933214</td>
#     </tr>
#     <tr>
#       <th id="T_669ea_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_669ea_row2_col0" class="data row2 col0" >45.000000</td>
#       <td id="T_669ea_row2_col1" class="data row2 col1" >47.840034</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_9ee33_">
#   <caption>Element 24</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9ee33_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_9ee33_row0_col0" class="data row0 col0" >276.000000</td>
#       <td id="T_9ee33_row0_col1" class="data row0 col1" >283.555775</td>
#     </tr>
#     <tr>
#       <th id="T_9ee33_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_9ee33_row1_col0" class="data row1 col0" >2414.000000</td>
#       <td id="T_9ee33_row1_col1" class="data row1 col1" >2464.044632</td>
#     </tr>
#     <tr>
#       <th id="T_9ee33_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_9ee33_row2_col0" class="data row2 col0" >48.000000</td>
#       <td id="T_9ee33_row2_col1" class="data row2 col1" >52.009535</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_37dfc_">
#   <caption>Element 25</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_37dfc_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_37dfc_row0_col0" class="data row0 col0" >259.000000</td>
#       <td id="T_37dfc_row0_col1" class="data row0 col1" >266.008241</td>
#     </tr>
#     <tr>
#       <th id="T_37dfc_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_37dfc_row1_col0" class="data row1 col0" >2312.000000</td>
#       <td id="T_37dfc_row1_col1" class="data row1 col1" >2412.793405</td>
#     </tr>
#     <tr>
#       <th id="T_37dfc_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_37dfc_row2_col0" class="data row2 col0" >47.000000</td>
#       <td id="T_37dfc_row2_col1" class="data row2 col1" >50.574839</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_52722_">
#   <caption>Element 26</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_52722_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_52722_row0_col0" class="data row0 col0" >258.000000</td>
#       <td id="T_52722_row0_col1" class="data row0 col1" >256.460870</td>
#     </tr>
#     <tr>
#       <th id="T_52722_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_52722_row1_col0" class="data row1 col0" >2343.000000</td>
#       <td id="T_52722_row1_col1" class="data row1 col1" >2354.234845</td>
#     </tr>
#     <tr>
#       <th id="T_52722_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_52722_row2_col0" class="data row2 col0" >48.000000</td>
#       <td id="T_52722_row2_col1" class="data row2 col1" >48.435677</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_bcf25_">
#   <caption>Element 27</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bcf25_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_bcf25_row0_col0" class="data row0 col0" >245.000000</td>
#       <td id="T_bcf25_row0_col1" class="data row0 col1" >250.643884</td>
#     </tr>
#     <tr>
#       <th id="T_bcf25_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_bcf25_row1_col0" class="data row1 col0" >2278.000000</td>
#       <td id="T_bcf25_row1_col1" class="data row1 col1" >2330.659863</td>
#     </tr>
#     <tr>
#       <th id="T_bcf25_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_bcf25_row2_col0" class="data row2 col0" >44.000000</td>
#       <td id="T_bcf25_row2_col1" class="data row2 col1" >47.668408</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_7b299_">
#   <caption>Element 28</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b299_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_7b299_row0_col0" class="data row0 col0" >267.000000</td>
#       <td id="T_7b299_row0_col1" class="data row0 col1" >266.503876</td>
#     </tr>
#     <tr>
#       <th id="T_7b299_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_7b299_row1_col0" class="data row1 col0" >2405.000000</td>
#       <td id="T_7b299_row1_col1" class="data row1 col1" >2394.089720</td>
#     </tr>
#     <tr>
#       <th id="T_7b299_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_7b299_row2_col0" class="data row2 col0" >52.000000</td>
#       <td id="T_7b299_row2_col1" class="data row2 col1" >50.248016</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_76b08_">
#   <caption>Element 29</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76b08_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_76b08_row0_col0" class="data row0 col0" >256.000000</td>
#       <td id="T_76b08_row0_col1" class="data row0 col1" >256.351610</td>
#     </tr>
#     <tr>
#       <th id="T_76b08_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_76b08_row1_col0" class="data row1 col0" >2365.000000</td>
#       <td id="T_76b08_row1_col1" class="data row1 col1" >2355.486548</td>
#     </tr>
#     <tr>
#       <th id="T_76b08_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_76b08_row2_col0" class="data row2 col0" >49.000000</td>
#       <td id="T_76b08_row2_col1" class="data row2 col1" >47.445963</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_2117e_">
#   <caption>Element 30</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2117e_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_2117e_row0_col0" class="data row0 col0" >276.000000</td>
#       <td id="T_2117e_row0_col1" class="data row0 col1" >282.713843</td>
#     </tr>
#     <tr>
#       <th id="T_2117e_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_2117e_row1_col0" class="data row1 col0" >2418.000000</td>
#       <td id="T_2117e_row1_col1" class="data row1 col1" >2460.632464</td>
#     </tr>
#     <tr>
#       <th id="T_2117e_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_2117e_row2_col0" class="data row2 col0" >49.000000</td>
#       <td id="T_2117e_row2_col1" class="data row2 col1" >51.898483</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_adebb_">
#   <caption>Element 31</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_adebb_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_adebb_row0_col0" class="data row0 col0" >274.000000</td>
#       <td id="T_adebb_row0_col1" class="data row0 col1" >285.622336</td>
#     </tr>
#     <tr>
#       <th id="T_adebb_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_adebb_row1_col0" class="data row1 col0" >2404.000000</td>
#       <td id="T_adebb_row1_col1" class="data row1 col1" >2472.419955</td>
#     </tr>
#     <tr>
#       <th id="T_adebb_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_adebb_row2_col0" class="data row2 col0" >47.000000</td>
#       <td id="T_adebb_row2_col1" class="data row2 col1" >52.282118</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_efa39_">
#   <caption>Element 32</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_efa39_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_efa39_row0_col0" class="data row0 col0" >229.000000</td>
#       <td id="T_efa39_row0_col1" class="data row0 col1" >233.184907</td>
#     </tr>
#     <tr>
#       <th id="T_efa39_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_efa39_row1_col0" class="data row1 col0" >2024.000000</td>
#       <td id="T_efa39_row1_col1" class="data row1 col1" >2054.027396</td>
#     </tr>
#     <tr>
#       <th id="T_efa39_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_efa39_row2_col0" class="data row2 col0" >35.000000</td>
#       <td id="T_efa39_row2_col1" class="data row2 col1" >36.247102</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_fb1ac_">
#   <caption>Element 33</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fb1ac_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_fb1ac_row0_col0" class="data row0 col0" >265.000000</td>
#       <td id="T_fb1ac_row0_col1" class="data row0 col1" >265.375846</td>
#     </tr>
#     <tr>
#       <th id="T_fb1ac_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_fb1ac_row1_col0" class="data row1 col0" >2398.000000</td>
#       <td id="T_fb1ac_row1_col1" class="data row1 col1" >2389.800479</td>
#     </tr>
#     <tr>
#       <th id="T_fb1ac_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_fb1ac_row2_col0" class="data row2 col0" >51.000000</td>
#       <td id="T_fb1ac_row2_col1" class="data row2 col1" >49.936677</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_dd979_">
#   <caption>Element 34</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd979_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_dd979_row0_col0" class="data row0 col0" >278.000000</td>
#       <td id="T_dd979_row0_col1" class="data row0 col1" >272.457580</td>
#     </tr>
#     <tr>
#       <th id="T_dd979_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_dd979_row1_col0" class="data row1 col0" >2435.000000</td>
#       <td id="T_dd979_row1_col1" class="data row1 col1" >2419.066047</td>
#     </tr>
#     <tr>
#       <th id="T_dd979_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_dd979_row2_col0" class="data row2 col0" >52.000000</td>
#       <td id="T_dd979_row2_col1" class="data row2 col1" >50.545667</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_e6a4e_">
#   <caption>Element 35</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6a4e_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_e6a4e_row0_col0" class="data row0 col0" >237.000000</td>
#       <td id="T_e6a4e_row0_col1" class="data row0 col1" >235.810774</td>
#     </tr>
#     <tr>
#       <th id="T_e6a4e_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_e6a4e_row1_col0" class="data row1 col0" >2125.000000</td>
#       <td id="T_e6a4e_row1_col1" class="data row1 col1" >2082.728677</td>
#     </tr>
#     <tr>
#       <th id="T_e6a4e_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_e6a4e_row2_col0" class="data row2 col0" >37.000000</td>
#       <td id="T_e6a4e_row2_col1" class="data row2 col1" >37.393321</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_de14a_">
#   <caption>Element 36</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_de14a_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_de14a_row0_col0" class="data row0 col0" >242.000000</td>
#       <td id="T_de14a_row0_col1" class="data row0 col1" >237.648880</td>
#     </tr>
#     <tr>
#       <th id="T_de14a_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_de14a_row1_col0" class="data row1 col0" >2182.000000</td>
#       <td id="T_de14a_row1_col1" class="data row1 col1" >2102.819574</td>
#     </tr>
#     <tr>
#       <th id="T_de14a_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_de14a_row2_col0" class="data row2 col0" >38.000000</td>
#       <td id="T_de14a_row2_col1" class="data row2 col1" >38.195674</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_418c4_">
#   <caption>Element 37</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_418c4_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_418c4_row0_col0" class="data row0 col0" >278.000000</td>
#       <td id="T_418c4_row0_col1" class="data row0 col1" >279.039958</td>
#     </tr>
#     <tr>
#       <th id="T_418c4_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_418c4_row1_col0" class="data row1 col0" >2430.000000</td>
#       <td id="T_418c4_row1_col1" class="data row1 col1" >2445.743001</td>
#     </tr>
#     <tr>
#       <th id="T_418c4_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_418c4_row2_col0" class="data row2 col0" >50.000000</td>
#       <td id="T_418c4_row2_col1" class="data row2 col1" >51.413892</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_ac9cd_">
#   <caption>Element 38</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ac9cd_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_ac9cd_row0_col0" class="data row0 col0" >259.000000</td>
#       <td id="T_ac9cd_row0_col1" class="data row0 col1" >265.745654</td>
#     </tr>
#     <tr>
#       <th id="T_ac9cd_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_ac9cd_row1_col0" class="data row1 col0" >2315.000000</td>
#       <td id="T_ac9cd_row1_col1" class="data row1 col1" >2409.923277</td>
#     </tr>
#     <tr>
#       <th id="T_ac9cd_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_ac9cd_row2_col0" class="data row2 col0" >47.000000</td>
#       <td id="T_ac9cd_row2_col1" class="data row2 col1" >50.460217</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_30580_">
#   <caption>Element 39</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_30580_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_30580_row0_col0" class="data row0 col0" >277.000000</td>
#       <td id="T_30580_row0_col1" class="data row0 col1" >270.391019</td>
#     </tr>
#     <tr>
#       <th id="T_30580_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_30580_row1_col0" class="data row1 col0" >2432.000000</td>
#       <td id="T_30580_row1_col1" class="data row1 col1" >2410.690725</td>
#     </tr>
#     <tr>
#       <th id="T_30580_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_30580_row2_col0" class="data row2 col0" >52.000000</td>
#       <td id="T_30580_row2_col1" class="data row2 col1" >50.273084</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_076d3_">
#   <caption>Element 40</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_076d3_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_076d3_row0_col0" class="data row0 col0" >280.000000</td>
#       <td id="T_076d3_row0_col1" class="data row0 col1" >280.040231</td>
#     </tr>
#     <tr>
#       <th id="T_076d3_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_076d3_row1_col0" class="data row1 col0" >2449.000000</td>
#       <td id="T_076d3_row1_col1" class="data row1 col1" >2445.560616</td>
#     </tr>
#     <tr>
#       <th id="T_076d3_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_076d3_row2_col0" class="data row2 col0" >55.000000</td>
#       <td id="T_076d3_row2_col1" class="data row2 col1" >53.984087</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_6d683_">
#   <caption>Element 41</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6d683_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_6d683_row0_col0" class="data row0 col0" >253.000000</td>
#       <td id="T_6d683_row0_col1" class="data row0 col1" >242.375440</td>
#     </tr>
#     <tr>
#       <th id="T_6d683_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_6d683_row1_col0" class="data row1 col0" >2294.000000</td>
#       <td id="T_6d683_row1_col1" class="data row1 col1" >2154.481879</td>
#     </tr>
#     <tr>
#       <th id="T_6d683_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_6d683_row2_col0" class="data row2 col0" >42.000000</td>
#       <td id="T_6d683_row2_col1" class="data row2 col1" >40.258869</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_20861_">
#   <caption>Element 42</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20861_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_20861_row0_col0" class="data row0 col0" >217.000000</td>
#       <td id="T_20861_row0_col1" class="data row0 col1" >229.508694</td>
#     </tr>
#     <tr>
#       <th id="T_20861_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_20861_row1_col0" class="data row1 col0" >1856.000000</td>
#       <td id="T_20861_row1_col1" class="data row1 col1" >2013.845603</td>
#     </tr>
#     <tr>
#       <th id="T_20861_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_20861_row2_col0" class="data row2 col0" >32.000000</td>
#       <td id="T_20861_row2_col1" class="data row2 col1" >34.642396</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_10d5a_">
#   <caption>Element 43</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_10d5a_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_10d5a_row0_col0" class="data row0 col0" >278.000000</td>
#       <td id="T_10d5a_row0_col1" class="data row0 col1" >278.912201</td>
#     </tr>
#     <tr>
#       <th id="T_10d5a_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_10d5a_row1_col0" class="data row1 col0" >2445.000000</td>
#       <td id="T_10d5a_row1_col1" class="data row1 col1" >2441.271375</td>
#     </tr>
#     <tr>
#       <th id="T_10d5a_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_10d5a_row2_col0" class="data row2 col0" >54.000000</td>
#       <td id="T_10d5a_row2_col1" class="data row2 col1" >53.672747</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_d77cd_">
#   <caption>Element 44</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
# ...
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a4c5_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_0a4c5_row0_col0" class="data row0 col0" >238.000000</td>
#       <td id="T_0a4c5_row0_col1" class="data row0 col1" >247.811931</td>
#     </tr>
#     <tr>
#       <th id="T_0a4c5_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_0a4c5_row1_col0" class="data row1 col0" >2240.000000</td>
#       <td id="T_0a4c5_row1_col1" class="data row1 col1" >2319.182569</td>
#     </tr>
#     <tr>
#       <th id="T_0a4c5_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_0a4c5_row2_col0" class="data row2 col0" >42.000000</td>
#       <td id="T_0a4c5_row2_col1" class="data row2 col1" >47.294869</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_db69e_">
#   <caption>Element 57</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db69e_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_db69e_row0_col0" class="data row0 col0" >278.000000</td>
#       <td id="T_db69e_row0_col1" class="data row0 col1" >271.615648</td>
#     </tr>
#     <tr>
#       <th id="T_db69e_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_db69e_row1_col0" class="data row1 col0" >2434.000000</td>
#       <td id="T_db69e_row1_col1" class="data row1 col1" >2415.653879</td>
#     </tr>
#     <tr>
#       <th id="T_db69e_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_db69e_row2_col0" class="data row2 col0" >52.000000</td>
#       <td id="T_db69e_row2_col1" class="data row2 col1" >50.434615</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_f5ee0_">
#   <caption>Element 58</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f5ee0_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_f5ee0_row0_col0" class="data row0 col0" >254.000000</td>
#       <td id="T_f5ee0_row0_col1" class="data row0 col1" >270.472214</td>
#     </tr>
#     <tr>
#       <th id="T_f5ee0_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_f5ee0_row1_col0" class="data row1 col0" >2290.000000</td>
#       <td id="T_f5ee0_row1_col1" class="data row1 col1" >2461.585582</td>
#     </tr>
#     <tr>
#       <th id="T_f5ee0_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_f5ee0_row2_col0" class="data row2 col0" >45.000000</td>
#       <td id="T_f5ee0_row2_col1" class="data row2 col1" >52.523411</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_f7419_">
#   <caption>Element 59</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f7419_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_f7419_row0_col0" class="data row0 col0" >277.000000</td>
#       <td id="T_f7419_row0_col1" class="data row0 col1" >270.008323</td>
#     </tr>
#     <tr>
#       <th id="T_f7419_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_f7419_row1_col0" class="data row1 col0" >2431.000000</td>
#       <td id="T_f7419_row1_col1" class="data row1 col1" >2409.139739</td>
#     </tr>
#     <tr>
#       <th id="T_f7419_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_f7419_row2_col0" class="data row2 col0" >52.000000</td>
#       <td id="T_f7419_row2_col1" class="data row2 col1" >50.222606</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_7c443_">
#   <caption>Element 60</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c443_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_7c443_row0_col0" class="data row0 col0" >265.000000</td>
#       <td id="T_7c443_row0_col1" class="data row0 col1" >259.752059</td>
#     </tr>
#     <tr>
#       <th id="T_7c443_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_7c443_row1_col0" class="data row1 col0" >2374.000000</td>
#       <td id="T_7c443_row1_col1" class="data row1 col1" >2367.573322</td>
#     </tr>
#     <tr>
#       <th id="T_7c443_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_7c443_row2_col0" class="data row2 col0" >50.000000</td>
#       <td id="T_7c443_row2_col1" class="data row2 col1" >48.869790</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_53d29_">
#   <caption>Element 61</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53d29_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_53d29_row0_col0" class="data row0 col0" >272.000000</td>
#       <td id="T_53d29_row0_col1" class="data row0 col1" >271.015994</td>
#     </tr>
#     <tr>
#       <th id="T_53d29_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_53d29_row1_col0" class="data row1 col0" >2422.000000</td>
#       <td id="T_53d29_row1_col1" class="data row1 col1" >2411.246686</td>
#     </tr>
#     <tr>
#       <th id="T_53d29_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_53d29_row2_col0" class="data row2 col0" >53.000000</td>
#       <td id="T_53d29_row2_col1" class="data row2 col1" >51.493373</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_0d4fc_">
#   <caption>Element 62</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Expected</th>
#       <th class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d4fc_level0_row0" class="row_heading level0 row0" >Average Particle Velocity</th>
#       <td id="T_0d4fc_row0_col0" class="data row0 col0" >264.000000</td>
#       <td id="T_0d4fc_row0_col1" class="data row0 col1" >259.292823</td>
#     </tr>
#     <tr>
#       <th id="T_0d4fc_level0_row1" class="row_heading level0 row1" >Average Particle Temperature</th>
#       <td id="T_0d4fc_row1_col0" class="data row1 col0" >2371.000000</td>
#       <td id="T_0d4fc_row1_col1" class="data row1 col1" >2365.712139</td>
#     </tr>
#     <tr>
#       <th id="T_0d4fc_level0_row2" class="row_heading level0 row2" >Average Particle Diameter</th>
#       <td id="T_0d4fc_row2_col0" class="data row2 col0" >50.000000</td>
#       <td id="T_0d4fc_row2_col1" class="data row2 col1" >48.809216</td>
#     </tr>
#   </tbody>
# </table>
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Iteration 1 - Pearson Correlation: 0.9999998140280801
# ------------------------------------------------------------------------
# > Iteration 2 - Pearson Correlation: 0.9999986695039575
# ------------------------------------------------------------------------
# > Iteration 3 - Pearson Correlation: 0.9999997659126658
# ------------------------------------------------------------------------
# > Iteration 4 - Pearson Correlation: 0.9999992594175392
# ------------------------------------------------------------------------
# > Iteration 5 - Pearson Correlation: 0.9999988782445357
# ------------------------------------------------------------------------
# > Iteration 6 - Pearson Correlation: 0.9999997578804085
# ------------------------------------------------------------------------
# > Iteration 7 - Pearson Correlation: 0.9999990937434433
# ------------------------------------------------------------------------
# > Iteration 8 - Pearson Correlation: 0.9999997335057319
# ------------------------------------------------------------------------
# > Iteration 9 - Pearson Correlation: 0.9999970521056538
# ------------------------------------------------------------------------
# > Iteration 10 - Pearson Correlation: 0.9999994715439038
# ------------------------------------------------------------------------
# > Iteration 11 - Pearson Correlation: 0.9999994719233749
# ------------------------------------------------------------------------
# > Iteration 12 - Pearson Correlation: 0.999999324944935
# ------------------------------------------------------------------------
# > Iteration 13 - Pearson Correlation: 0.99999984898622
# ------------------------------------------------------------------------
# > Iteration 14 - Pearson Correlation: 0.9999998883855272
# ------------------------------------------------------------------------
# > Iteration 15 - Pearson Correlation: 0.9999993819698499
# ------------------------------------------------------------------------
# > Iteration 16 - Pearson Correlation: 0.9999995143075435
# ------------------------------------------------------------------------
# > Iteration 17 - Pearson Correlation: 0.9999999312136241
# ------------------------------------------------------------------------
# > Iteration 18 - Pearson Correlation: 0.9999980823185922
# ------------------------------------------------------------------------
# > Iteration 19 - Pearson Correlation: 0.9999993476719784
# ------------------------------------------------------------------------
# > Iteration 20 - Pearson Correlation: 0.9999997019722277
# ------------------------------------------------------------------------
# > Iteration 21 - Pearson Correlation: 0.9999993815686183
# ------------------------------------------------------------------------
# > Iteration 22 - Pearson Correlation: 0.9999997309231456
# ------------------------------------------------------------------------
# > Iteration 23 - Pearson Correlation: 0.9999994625237572
# ------------------------------------------------------------------------
# > Iteration 24 - Pearson Correlation: 0.9999999387681904
# ------------------------------------------------------------------------
# > Iteration 25 - Pearson Correlation: 0.9999974294000802
# ------------------------------------------------------------------------
# > Iteration 26 - Pearson Correlation: 0.9999992642520441
# ------------------------------------------------------------------------
# > Iteration 27 - Pearson Correlation: 0.9999994954638938
# ------------------------------------------------------------------------
# > Iteration 28 - Pearson Correlation: 0.9999996441975194
# ------------------------------------------------------------------------
# > Iteration 29 - Pearson Correlation: 0.9999994280680822
# ------------------------------------------------------------------------
# > Iteration 30 - Pearson Correlation: 0.9999999999950294
# ------------------------------------------------------------------------
# > Iteration 31 - Pearson Correlation: 0.9999999948274252
# ------------------------------------------------------------------------
# > Iteration 32 - Pearson Correlation: 0.9999999981087909
# ------------------------------------------------------------------------
# > Iteration 33 - Pearson Correlation: 0.9999996440731513
# ------------------------------------------------------------------------
# > Iteration 34 - Pearson Correlation: 0.9999994110333879
# ------------------------------------------------------------------------
# > Iteration 35 - Pearson Correlation: 0.9999993255257174
# ------------------------------------------------------------------------
# > Iteration 36 - Pearson Correlation: 0.9999990471533704
# ------------------------------------------------------------------------
# > Iteration 37 - Pearson Correlation: 0.9999997609508209
# ------------------------------------------------------------------------
# > Iteration 38 - Pearson Correlation: 0.9999977762476702
# ------------------------------------------------------------------------
# > Iteration 39 - Pearson Correlation: 0.9999992614177516
# ------------------------------------------------------------------------
# > Iteration 40 - Pearson Correlation: 0.9999998708056688
# ------------------------------------------------------------------------
# > Iteration 41 - Pearson Correlation: 0.9999983737603941
# ------------------------------------------------------------------------
# > Iteration 42 - Pearson Correlation: 0.9999960099732188
# ------------------------------------------------------------------------
# > Iteration 43 - Pearson Correlation: 0.9999998091786353
# ------------------------------------------------------------------------
# > Iteration 44 - Pearson Correlation: 0.9999995284671525
# ------------------------------------------------------------------------
# > Iteration 45 - Pearson Correlation: 0.9999996743367741
# ------------------------------------------------------------------------
# > Iteration 46 - Pearson Correlation: 0.9999995469869629
# ------------------------------------------------------------------------
# > Iteration 47 - Pearson Correlation: 0.999997209790632
# ------------------------------------------------------------------------
# > Iteration 48 - Pearson Correlation: 0.9999996482597627
# ------------------------------------------------------------------------
# > Iteration 49 - Pearson Correlation: 0.9999988154091088
# ------------------------------------------------------------------------
# > Iteration 50 - Pearson Correlation: 0.9999989338201007
# ------------------------------------------------------------------------
# > Iteration 51 - Pearson Correlation: 0.9999993499798003
# ------------------------------------------------------------------------
# > Iteration 52 - Pearson Correlation: 0.9999991886627739
# ------------------------------------------------------------------------
# > Iteration 53 - Pearson Correlation: 0.9999997563646188
# ------------------------------------------------------------------------
# > Iteration 54 - Pearson Correlation: 0.9999986788863084
# ------------------------------------------------------------------------
# > Iteration 55 - Pearson Correlation: 0.999999259131024
# ------------------------------------------------------------------------
# > Iteration 56 - Pearson Correlation: 0.9999996309260164
# ------------------------------------------------------------------------
# > Iteration 57 - Pearson Correlation: 0.9999991657274611
# ------------------------------------------------------------------------
# > Iteration 58 - Pearson Correlation: 0.9999969237975623
# ------------------------------------------------------------------------
# > Iteration 59 - Pearson Correlation: 0.9999991153684367
# ------------------------------------------------------------------------
# > Iteration 60 - Pearson Correlation: 0.999998907620225
# ------------------------------------------------------------------------
# > Iteration 61 - Pearson Correlation: 0.9999998476751848
# ------------------------------------------------------------------------
# > Iteration 62 - Pearson Correlation: 0.9999991813496648
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Average Pearsons Correlation: 0.9999992001670279 - Standard Deviation: 8.181046165708515e-07
# ------------------------------------------------------------------------
